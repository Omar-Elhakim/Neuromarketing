# %% [markdown]
# <a href="https://www.kaggle.com/code/omarelhakim0/eeg-emotion-classification-on-seediv?scriptVersionId=282265350" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !pip install torch_scatter torcheeg torch_geometric -qq

# %%
# !rm -rf tmp_out

# %%
import torch
import torch.nn as nn
import torch.nn.utils as utils
from torch.utils.data import DataLoader, Subset
from torcheeg.models import CCNN
from torcheeg import transforms
from torcheeg.transforms import ToGrid
from torcheeg.datasets import SEEDIVDataset,SEEDIVFeatureDataset
from torcheeg.datasets.constants import SEED_IV_CHANNEL_LOCATION_DICT
from torcheeg.transforms import ToG
from torcheeg.datasets.constants import SEED_IV_ADJACENCY_MATRIX
from torcheeg.models import DGCNN
import torch_geometric.loader as geom_loader # Special loader for graphs
import copy
import scipy.signal as signal
import random

# %%
# 1. Setup Device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def BandPassFilter(eeg_data):
    b, a = signal.butter(4, Wn=[1.0, 75.0], btype='bandpass', fs=200)
    return signal.filtfilt(b, a, eeg_data, axis=-1)

# %%
def Notch(eeg_data):
    b, a = signal.iirnotch(w0=50.0, Q=30.0, fs=200)
    return signal.filtfilt(b, a, eeg_data, axis=-1)

# %%
# 2. Define Preprocessing
t_transform = transforms.Compose([
    transforms.Lambda(BandPassFilter),
    transforms.Lambda(Notch),
    transforms.BaselineRemoval(),
    transforms.MeanStdNormalize(),
    transforms.To2d()
    
])

# %%
def map_emotions(y):
    # Input y is 0, 1, 2, or 3
    if y == 0: 
        return 0  # Neutral remains 0
    elif y == 1 or y == 2: 
        return 1  # Sad (1) and Fear (2) become Negative (1)
    elif y == 3: 
        return 2  # Happy (3) becomes Positive (2)
    return 0

# %%
dataset = SEEDIVFeatureDataset(
    io_path='./tmp_out/seed_iv_features',
    root_path='/kaggle/input/seed-iv/eeg_feature_smooth',
    feature=['de_LDS'], 
    num_worker=0,
    offline_transform=transforms.Compose([
        # FIX: Use To2d to get a Tensor (Electrodes, Features)
        # We don't need ToGrid (Images) or ToG (Graphs)
        transforms.To2d(), 
        transforms.Lambda(lambda x: torch.tensor(x).float())    ]),
    label_transform=transforms.Compose([
        transforms.Select('emotion'),
        transforms.Lambda(map_emotions)
    ])
)
# Out:
# [2025-11-27 17:59:24] INFO (torcheeg/MainThread) 🔍 | Detected cached processing results, reading cache from ./tmp_out/seed_iv_features.

# %%
import pandas as pd

# 1. Get the metadata DataFrame
df = dataset.info

# 2. Count the segments for each emotion
# 0: Neutral, 1: Sad, 2: Fear, 3: Happy
counts = df['emotion'].value_counts().sort_index()
total = len(df)

print(f"Total Segments: {total}")
print("-" * 30)
print("Count per Emotion:")
print(counts)

print("-" * 30)
print("Percentage per Emotion:")
percentages = (counts / total) * 100
print(percentages.round(2))

# 3. Check for Imbalance
# If the difference between max and min is > 10%, we might need a WeightedSampler
max_pct = percentages.max()
min_pct = percentages.min()

if (max_pct - min_pct) > 10:
    print(f"\n⚠️ WARNING: Data is IMBALANCED (Diff: {max_pct - min_pct:.2f}%)")
    print("Consider using a WeightedRandomSampler.")
else:
    print(f"\n✅ Data is reasonably BALANCED (Diff: {max_pct - min_pct:.2f}%)")
# Out:
# Total Segments: 37575
# ------------------------------
# Count per Emotion:
# emotion
# 0    10170
# 1    10245
# 2     9225
# 3     7935
# Name: count, dtype: int64
# ------------------------------
# Percentage per Emotion:
# emotion
# 0    27.07
# 1    27.27
# 2    24.55
# 3    21.12
# Name: count, dtype: float64
#
# ✅ Data is reasonably BALANCED (Diff: 6.15%)

# %%
# Split by Trial ID
# SEED-IV has 24 trials (videos) per session.
# 80% of VIDEOS for training (19 videos), 20% for testing (5 videos).
all_trial_ids = list(range(1, 25))

random.seed(42)
test_trial_ids = random.sample(all_trial_ids, 5)
train_trial_ids = [t for t in all_trial_ids if t not in test_trial_ids]

train_indices = df[df['trial_id'].isin(train_trial_ids)].index.tolist()
test_indices = df[df['trial_id'].isin(test_trial_ids)].index.tolist()

# Create Subsets & Loaders
train_set = Subset(dataset, train_indices)
test_set = Subset(dataset, test_indices)

train_loader = DataLoader(train_set, batch_size=64, shuffle=True)
test_loader = DataLoader(test_set, batch_size=64, shuffle=False)

# %%
model = DGCNN(
    in_channels=5,      # 5 Frequency Bands
    num_electrodes=62, 
    num_layers=2,       # Standard depth
    hid_channels=32,
    num_classes=3,
).to(device)

# Add weights to classes
weights = torch.tensor([1.0, 0.9, 1.4]).to(device)
weights = weights / weights.sum() * 3.0

criterion = nn.CrossEntropyLoss(weight=weights, label_smoothing=0.25)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0005, weight_decay=0.01)
# Scheduler: If validation loss doesn't go down for 3 epochs, cut LR by half
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)

# %%
# Early Stopping
patience = 15
counter = 0
best_val_acc = 0.0
best_model_state = None

for epoch in range(100):
    model.train()
    train_loss = 0
    correct = 0
    total = 0
    
    for batch in train_loader:
        X, y = batch
        X = X.squeeze(1)
        X = X.to(device)
        y = y.to(device).long()
        
        optimizer.zero_grad()
        outputs = model(X)
        loss = criterion(outputs, y)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += y.size(0)
        correct += (predicted == y).sum().item()
    
    train_acc = 100 * correct / total
    
    # --- VALIDATION ---
    model.eval()
    val_correct = 0
    val_total = 0
    val_loss = 0
    
    with torch.no_grad():
        for batch in test_loader:
            X, y = batch
            
            # Same shape logic for validation
            X = X.squeeze(1)
            if X.shape[-1] == 62:
                X = X.transpose(1, 2)
            
            X = X.to(device)
            y = y.to(device).long()
            
            outputs = model(X)
            loss = criterion(outputs, y)
            val_loss += loss.item()
            
            _, predicted = torch.max(outputs.data, 1)
            val_total += y.size(0)
            val_correct += (predicted == y).sum().item()
            
    val_acc = 100 * val_correct / val_total
    avg_val_loss = val_loss / len(test_loader)
    
    scheduler.step(avg_val_loss)
    
    print(f"Epoch {epoch+1}: Train Acc={train_acc:.2f}% | Val Acc={val_acc:.2f}% | Val Loss={avg_val_loss:.4f}")

    # --- EARLY STOPPING ---
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_model_state = copy.deepcopy(model.state_dict())
        torch.save(model.state_dict(), 'best_dgcnn_final.pth')
        print(f"  --> New Best! {best_val_acc:.2f}%")
        counter = 0
    else:
        counter += 1
        if counter >= patience:
            print("  --> Early Stopping.")
            break

if best_model_state:
    model.load_state_dict(best_model_state)
    print(f"Finished. Best Acc: {best_val_acc:.2f}%")
# Out:
# Epoch 1: Train Acc=67.70% | Val Acc=61.36% | Val Loss=1.0135
#   --> New Best! 61.36%
# Epoch 2: Train Acc=77.97% | Val Acc=62.10% | Val Loss=0.9906
#   --> New Best! 62.10%
# Epoch 3: Train Acc=81.82% | Val Acc=68.75% | Val Loss=0.9457
#   --> New Best! 68.75%
# Epoch 4: Train Acc=84.36% | Val Acc=67.68% | Val Loss=0.9560
# Epoch 5: Train Acc=85.80% | Val Acc=63.57% | Val Loss=0.9788
# Epoch 6: Train Acc=87.01% | Val Acc=69.63% | Val Loss=0.9573
#   --> New Best! 69.63%
# Epoch 7: Train Acc=87.81% | Val Acc=67.02% | Val Loss=0.9549
# Epoch 8: Train Acc=90.08% | Val Acc=67.84% | Val Loss=0.9635
# Epoch 9: Train Acc=90.47% | Val Acc=73.16% | Val Loss=0.9172
#   --> New Best! 73.16%
# Epoch 10: Train Acc=91.23% | Val Acc=70.10% | Val Loss=0.9448
# Epoch 11: Train Acc=91.39% | Val Acc=69.45% | Val Loss=0.9306
# Epoch 12: Train Acc=91.89% | Val Acc=70.94% | Val Loss=0.9352
# Epoch 13: Train Acc=92.22% | Val Acc=74.88% | Val Loss=0.9090
#   --> New Best! 74.88%
# Epoch 14: Train Acc=92.52% | Val Acc=71.64% | Val Loss=0.9251
# Epoch 15: Train Acc=92.38% | Val Acc=75.50% | Val Loss=0.9097
#   --> New Best! 75.50%
# Epoch 16: Train Acc=92.81% | Val Acc=72.43% | Val Loss=0.9318
# Epoch 17: Train Acc=92.76% | Val Acc=74.52% | Val Loss=0.9127
# Epoch 18: Train Acc=94.15% | Val Acc=74.17% | Val Loss=0.9254
# Epoch 19: Train Acc=94.38% | Val Acc=71.70% | Val Loss=0.9286
# Epoch 20: Train Acc=94.61% | Val Acc=72.10% | Val Loss=0.9320
# Epoch 21: Train Acc=94.68% | Val Acc=72.25% | Val Loss=0.9272
# Epoch 22: Train Acc=95.41% | Val Acc=75.92% | Val Loss=0.9085
#   --> New Best! 75.92%
# Epoch 23: Train Acc=95.42% | Val Acc=73.26% | Val Loss=0.9340
# Epoch 24: Train Acc=95.84% | Val Acc=73.68% | Val Loss=0.9157
# Epoch 25: Train Acc=95.64% | Val Acc=73.57% | Val Loss=0.9115
# Epoch 26: Train Acc=95.97% | Val Acc=74.77% | Val Loss=0.9126
# Epoch 27: Train Acc=96.40% | Val Acc=74.68% | Val Loss=0.9151
# Epoch 28: Train Acc=96.51% | Val Acc=75.17% | Val Loss=0.9173
# Epoch 29: Train Acc=96.31% | Val Acc=75.17% | Val Loss=0.9264
# Epoch 30: Train Acc=96.34% | Val Acc=75.31% | Val Loss=0.9111
# Epoch 31: Train Acc=96.78% | Val Acc=74.04% | Val Loss=0.9238
# Epoch 32: Train Acc=96.80% | Val Acc=75.83% | Val Loss=0.9161
# Epoch 33: Train Acc=96.74% | Val Acc=75.99% | Val Loss=0.9112
#   --> New Best! 75.99%
# Epoch 34: Train Acc=96.88% | Val Acc=74.18% | Val Loss=0.9184
# Epoch 35: Train Acc=96.93% | Val Acc=75.58% | Val Loss=0.9217
# Epoch 36: Train Acc=96.88% | Val Acc=76.03% | Val Loss=0.9202
#   --> New Best! 76.03%
# Epoch 37: Train Acc=97.01% | Val Acc=75.48% | Val Loss=0.9208
# Epoch 38: Train Acc=97.03% | Val Acc=76.30% | Val Loss=0.9139
#   --> New Best! 76.30%
# Epoch 39: Train Acc=97.24% | Val Acc=75.49% | Val Loss=0.9176
# Epoch 40: Train Acc=97.00% | Val Acc=75.88% | Val Loss=0.9182
# Epoch 41: Train Acc=97.07% | Val Acc=76.29% | Val Loss=0.9136
# Epoch 42: Train Acc=97.29% | Val Acc=76.18% | Val Loss=0.9160
# Epoch 43: Train Acc=97.10% | Val Acc=76.30% | Val Loss=0.9151
# Epoch 44: Train Acc=97.16% | Val Acc=76.29% | Val Loss=0.9148
# Epoch 45: Train Acc=97.05% | Val Acc=75.15% | Val Loss=0.9245
# Epoch 46: Train Acc=97.07% | Val Acc=76.54% | Val Loss=0.9148
#   --> New Best! 76.54%
# Epoch 47: Train Acc=97.17% | Val Acc=75.64% | Val Loss=0.9182
# Epoch 48: Train Acc=97.32% | Val Acc=75.74% | Val Loss=0.9178
# Epoch 49: Train Acc=97.23% | Val Acc=76.29% | Val Loss=0.9152
# Epoch 50: Train Acc=97.22% | Val Acc=76.10% | Val Loss=0.9168
# Epoch 51: Train Acc=97.25% | Val Acc=76.10% | Val Loss=0.9167
# Epoch 52: Train Acc=97.16% | Val Acc=76.20% | Val Loss=0.9182
# Epoch 53: Train Acc=97.08% | Val Acc=75.01% | Val Loss=0.9246
# Epoch 54: Train Acc=97.11% | Val Acc=76.13% | Val Loss=0.9203
# Epoch 55: Train Acc=97.19% | Val Acc=76.04% | Val Loss=0.9184
# Epoch 56: Train Acc=97.00% | Val Acc=76.10% | Val Loss=0.9149
# Epoch 57: Train Acc=97.02% | Val Acc=75.60% | Val Loss=0.9200
# Epoch 58: Train Acc=97.13% | Val Acc=75.96% | Val Loss=0.9189
# Epoch 59: Train Acc=97.12% | Val Acc=75.81% | Val Loss=0.9149
# Epoch 60: Train Acc=97.24% | Val Acc=76.65% | Val Loss=0.9113
#   --> New Best! 76.65%
# Epoch 61: Train Acc=97.01% | Val Acc=76.20% | Val Loss=0.9167
# Epoch 62: Train Acc=97.19% | Val Acc=76.57% | Val Loss=0.9172
# Epoch 63: Train Acc=97.12% | Val Acc=76.27% | Val Loss=0.9150
# Epoch 64: Train Acc=97.17% | Val Acc=74.90% | Val Loss=0.9241
# Epoch 65: Train Acc=97.20% | Val Acc=76.48% | Val Loss=0.9178
# Epoch 66: Train Acc=97.17% | Val Acc=76.46% | Val Loss=0.9142
# Epoch 67: Train Acc=97.20% | Val Acc=75.20% | Val Loss=0.9216
# Epoch 68: Train Acc=97.13% | Val Acc=76.32% | Val Loss=0.9179
# Epoch 69: Train Acc=97.17% | Val Acc=75.11% | Val Loss=0.9261
# Epoch 70: Train Acc=97.09% | Val Acc=75.77% | Val Loss=0.9195
# Epoch 71: Train Acc=97.02% | Val Acc=75.94% | Val Loss=0.9211
# Epoch 72: Train Acc=97.21% | Val Acc=75.59% | Val Loss=0.9197
# Epoch 73: Train Acc=97.15% | Val Acc=75.98% | Val Loss=0.9214
# Epoch 74: Train Acc=97.10% | Val Acc=76.31% | Val Loss=0.9150
# Epoch 75: Train Acc=97.28% | Val Acc=76.54% | Val Loss=0.9153
#   --> Early Stopping.
# Finished. Best Acc: 76.65%

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# 1. Get Predictions for the entire Test Set
model.eval()
y_true = []
y_pred = []

print("Generating confusion matrix...")

with torch.no_grad():
    for batch in test_loader:
        X, y = batch
        
        # Apply the same Shape Fix logic
        X = X.squeeze(1)
        if X.shape[-1] == 62:
             X = X.transpose(1, 2)
             
        X = X.to(device)
        y = y.to(device)
        
        outputs = model(X)
        _, predicted = torch.max(outputs, 1)
        
        y_true.extend(y.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())

# 2. Define Emotion Labels
# 0: Neutral, 1: Sad, 2: Fear, 3: Happy
emotion_labels = ['Neutral', 'Negative', 'Positive']

# 3. Create Matrix
cm = confusion_matrix(y_true, y_pred)
# Normalize it to show Percentages instead of raw numbers
cm_pct = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# 4. Plot
plt.figure(figsize=(10, 8))
sns.heatmap(cm_pct, annot=True, fmt='.2%', cmap='Blues', 
            xticklabels=emotion_labels, yticklabels=emotion_labels)
plt.xlabel('Predicted Emotion')
plt.ylabel('True Emotion')
plt.title('DGCNN Confusion Matrix (SEED-IV)')
plt.show()

# 5. Print Detailed Report
print(classification_report(y_true, y_pred, target_names=emotion_labels))
# Out:
# Generating confusion matrix...
#               precision    recall  f1-score   support
#
#      Neutral       0.86      0.70      0.77      3120
#     Negative       0.86      0.79      0.82      4020
#     Positive       0.46      0.89      0.61      1020
#
#     accuracy                           0.77      8160
#    macro avg       0.73      0.79      0.74      8160
# weighted avg       0.81      0.77      0.78      8160
