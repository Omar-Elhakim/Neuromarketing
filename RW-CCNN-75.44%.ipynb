# %% [markdown]
# <a href="https://www.kaggle.com/code/rawanmoamed/eeg-classification-ccnn?scriptVersionId=295594625" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !pip install torch_scatter torcheeg torch_geometric -qq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.4/251.4 kB 14.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.5/231.5 kB 17.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 50.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.1/295.1 kB 21.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 51.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.2/115.2 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.1/34.1 MB 56.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 15.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 93.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 78.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 62.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 28.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 64.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.2/750.2 kB 49.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 68.6 MB/s eta 0:00:00
#   Building wheel for torch_scatter (setup.py) ... done
#   Building wheel for torcheeg (setup.py) ... done
#   Building wheel for spectrum (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kaggle-environments 1.18.0 requires scipy>=1.11.2, but you have scipy 1.10.1 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.5.2 requires scipy>=1.11.1, but you have scipy 1.10.1 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.10.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# scikit-image 0.25.2 requires scipy>=1.11.4, but you have scipy 1.10.1 which is incompatible.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# cvxpy 1.6.7 requires scipy>=1.11.0, but you have scipy 1.10.1 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# xarray-einstats 0.9.1 requires scipy>=1.11, but you have scipy 1.10.1 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# jaxlib 0.5.1 requires scipy>=1.11.1, but you have scipy 1.10.1 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.

# %%
import torch
import torch.nn as nn
import torch.nn.utils as utils
from torch.utils.data import DataLoader, Subset,WeightedRandomSampler
from torcheeg.models import CCNN
from torcheeg import transforms
from torcheeg.transforms import ToGrid
from torcheeg.datasets import SEEDIVDataset,SEEDIVFeatureDataset
from torcheeg.datasets.constants import SEED_IV_CHANNEL_LOCATION_DICT
from torcheeg.transforms import ToG
from torcheeg.datasets.constants import SEED_IV_ADJACENCY_MATRIX
from torcheeg.models import DGCNN
from torch.optim.lr_scheduler import CosineAnnealingLR
from torch.optim.lr_scheduler import ReduceLROnPlateau 
# --- THE MAIN SUBJECT LOOP ---

import torch_geometric.loader as geom_loader # Special loader for graphs
import copy
import scipy.signal as signal
import random
import numpy as np

# %%
import shutil
import os

if os.path.exists('./tmp_out/seed_iv_features'):
    shutil.rmtree('./tmp_out/seed_iv_features')
    print("Old cache deleted. Data will be re-processed.")

# %%
# 1. Setup Device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_everything(42)

# %%
def weights_init(m):
    if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
        nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
        if m.bias is not None:
            nn.init.constant_(m.bias, 0)

# %%
from torcheeg.datasets.constants import SEED_IV_CHANNEL_LOCATION_DICT
from torcheeg.transforms import ToGrid



dataset = SEEDIVFeatureDataset(
    io_path='./tmp_out/seed_iv_features',
    root_path='/kaggle/input/seed-iv/eeg_feature_smooth',
    feature=['de_LDS'],

    offline_transform=transforms.Compose([
        ToGrid(SEED_IV_CHANNEL_LOCATION_DICT),
        transforms.MinMaxNormalize(),
        transforms.Lambda(lambda x: torch.tensor(x).float())
    ]),

    label_transform=transforms.Compose([
        transforms.Select('emotion')
    ]),

    io_mode='memory'
)
# Out:
# [2026-02-03 05:59:29] INFO (torcheeg/MainThread) 🔍 | Processing EEG data. Processed EEG data has been cached to ./tmp_out/seed_iv_features.
# [2026-02-03 05:59:29] INFO (torcheeg/MainThread) ⏳ | Monitoring the detailed processing of a record for debugging. The processing of other records will only be reported in percentage to keep it clean.
# [PROCESS]:   0%|          | 0/45 [00:00<?, ?it/s]
# [RECORD /kaggle/input/seed-iv/eeg_feature_smooth/1/4_20151111.mat]: 0it [00:00, ?it/s]
# [RECORD /kaggle/input/seed-iv/eeg_feature_smooth/1/4_20151111.mat]: 1it [00:00,  9.48it/s]
# [RECORD /kaggle/input/seed-iv/eeg_feature_smooth/1/4_20151111.mat]: 510it [00:00, 2929.09it/s]
# [PROCESS]: 100%|██████████| 45/45 [00:10<00:00,  4.33it/s]

# %%
subjects = sorted(dataset.info['subject_id'].unique()) # Get list of all 15 subjects

# %%
def train_one_epoch(model, loader, optimizer, criterion):
    model.train()
    total_loss = 0
    correct = 0
    total = 0

    for batch in loader:
        x = batch[0].to(device)
        y = batch[1].to(device)


        optimizer.zero_grad()
        out = model(x)
        loss = criterion(out, y)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        preds = out.argmax(dim=1)
        correct += (preds == y).sum().item()
        total += y.size(0)

    return total_loss / len(loader), correct / total

# %%
def evaluate(model, loader, criterion):
    model.eval()
    correct, total = 0, 0
    total_loss = 0

    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device), y.to(device)

            out = model(x)
            loss = criterion(out, y)

            total_loss += loss.item()
            preds = out.argmax(dim=1)

            correct += (preds == y).sum().item()
            total += y.size(0)

    return total_loss / len(loader), correct / total

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class CustomCCNN(nn.Module):
    def __init__(self, in_channels=5, num_classes=4, grid_size=(9,9), dropout=0.5):
        super(CustomCCNN, self).__init__()
        self.grid_h, self.grid_w = grid_size
        
        # --- Convolutional Layers ---
        self.conv1 = nn.Conv2d(in_channels, 16, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(16)
        
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(32)
        
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(64)
        
        self.dropout = nn.Dropout(dropout)
        
        # Global Average Pooling
        self.gap = nn.AdaptiveAvgPool2d((1,1))
        
        # Fully connected layer
        self.fc = nn.Linear(64, num_classes)

    def forward(self, x):
        # x shape: (B, C, H, W)
        x = F.leaky_relu(self.bn1(self.conv1(x)))
        x = F.leaky_relu(self.bn2(self.conv2(x)))
        x = F.leaky_relu(self.bn3(self.conv3(x)))
        
        x = self.dropout(x)
        x = self.gap(x)             # (B, 64, 1, 1)
        x = x.view(x.size(0), -1)   # flatten to (B, 64)
        x = self.fc(x)
        return x

# %%
all_subject_accuracies = []

for subject_id in subjects:
    print(f"\nProcessing SUBJECT: {subject_id}")
    
    # --- Data Split by Trials ---
    sub_df = dataset.info[dataset.info['subject_id'] == subject_id]
    all_trials = list(range(1, 25))
    random.seed(42)
    test_trials = random.sample(all_trials, 5)
    train_trials = [t for t in all_trials if t not in test_trials]

    train_indices = sub_df[sub_df['trial_id'].isin(train_trials)].index.tolist()
    test_indices = sub_df[sub_df['trial_id'].isin(test_trials)].index.tolist()

    train_set = Subset(dataset, train_indices)
    test_set = Subset(dataset, test_indices)

    # --- Weighted Sampler ---
    y_train_indices = train_set.indices
    raw_labels = dataset.info.iloc[y_train_indices]['emotion'].values
    class_counts = np.bincount(raw_labels)
    class_weights = 1. / class_counts
    sample_weights = [class_weights[y] for y in raw_labels]
    sampler = WeightedRandomSampler(weights=sample_weights, num_samples=len(sample_weights), replacement=True)

    train_loader = DataLoader(train_set, batch_size=32, sampler=sampler, num_workers=0)
    test_loader = DataLoader(test_set, batch_size=32, shuffle=False, num_workers=0)

    # --- Model ---
    model = CustomCCNN(
        in_channels=5,
        num_classes=4,
        grid_size=(9,9),
        dropout=0.35
    ).to(device)
    model.apply(weights_init)

    # --- Criterion & Optimizer ---
    criterion = nn.CrossEntropyLoss(label_smoothing=0.1).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
    scheduler = CosineAnnealingLR(optimizer, T_max=100)

    epochs = 70
    best_acc = 0.0

    # --- Training Loop ---
    for epoch in range(epochs):
        model.train()
        train_loss_sum = 0
        correct = 0
        total = 0

        for x, y in train_loader:
            x, y = x.to(device), y.to(device)

            optimizer.zero_grad()
            out = model(x)
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()

            train_loss_sum += loss.item()
            preds = out.argmax(dim=1)
            correct += (preds == y).sum().item()
            total += y.size(0)

        avg_train_loss = train_loss_sum / len(train_loader)
        train_acc = correct / total

        val_loss, val_acc = evaluate(model, test_loader, criterion)
        scheduler.step()

        if val_acc > best_acc:
            best_acc = val_acc
            print(f"Epoch {epoch+1}/{epochs} | Train Loss: {avg_train_loss:.4f} | "
                  f"Val Loss: {val_loss:.4f} | Train Acc: {train_acc:.3f} | "
                  f"Val Acc: {val_acc:.3f} (*) BEST")

    all_subject_accuracies.append(best_acc)
    print(f"Subject {subject_id} FINAL BEST ACC: {best_acc*100:.2f}%")

# --- Final Summary ---
print("\n" + "="*50)
print("FINAL RESULTS SUMMARY")
print("="*50)
final_avg_acc = np.mean(all_subject_accuracies)
final_std_acc = np.std(all_subject_accuracies)
print(f"Subjects: {len(subjects)} | Average Accuracy: {final_avg_acc*100:.2f}% | Std: {final_std_acc*100:.2f}")
print(f"Accuracies List: {[round(x*100,2) for x in all_subject_accuracies]}")
# Out:
# Processing SUBJECT: 1
# Epoch 1/70 | Train Loss: 1.7848 | Val Loss: 1.3830 | Train Acc: 0.251 | Val Acc: 0.428 (*) BEST
# Epoch 15/70 | Train Loss: 1.0351 | Val Loss: 1.3914 | Train Acc: 0.621 | Val Acc: 0.465 (*) BEST
# Epoch 22/70 | Train Loss: 0.9243 | Val Loss: 1.4347 | Train Acc: 0.672 | Val Acc: 0.467 (*) BEST
# Epoch 23/70 | Train Loss: 0.9204 | Val Loss: 1.1735 | Train Acc: 0.677 | Val Acc: 0.493 (*) BEST
# Epoch 24/70 | Train Loss: 0.9085 | Val Loss: 1.3414 | Train Acc: 0.701 | Val Acc: 0.555 (*) BEST
# Epoch 29/70 | Train Loss: 0.8506 | Val Loss: 1.1437 | Train Acc: 0.744 | Val Acc: 0.610 (*) BEST
# Epoch 32/70 | Train Loss: 0.7967 | Val Loss: 1.0712 | Train Acc: 0.781 | Val Acc: 0.711 (*) BEST
# Epoch 37/70 | Train Loss: 0.7618 | Val Loss: 0.9542 | Train Acc: 0.804 | Val Acc: 0.776 (*) BEST
# Subject 1 FINAL BEST ACC: 77.57%
#
# Processing SUBJECT: 2
# Epoch 1/70 | Train Loss: 1.5766 | Val Loss: 1.5407 | Train Acc: 0.310 | Val Acc: 0.221 (*) BEST
# Epoch 2/70 | Train Loss: 1.3282 | Val Loss: 1.3781 | Train Acc: 0.424 | Val Acc: 0.285 (*) BEST
# Epoch 4/70 | Train Loss: 1.1014 | Val Loss: 1.2728 | Train Acc: 0.556 | Val Acc: 0.404 (*) BEST
# Epoch 5/70 | Train Loss: 1.0508 | Val Loss: 1.1736 | Train Acc: 0.594 | Val Acc: 0.443 (*) BEST
# Epoch 9/70 | Train Loss: 0.8975 | Val Loss: 1.1581 | Train Acc: 0.716 | Val Acc: 0.614 (*) BEST
# Epoch 37/70 | Train Loss: 0.5488 | Val Loss: 1.0503 | Train Acc: 0.942 | Val Acc: 0.680 (*) BEST
# Epoch 59/70 | Train Loss: 0.4701 | Val Loss: 1.0090 | Train Acc: 0.982 | Val Acc: 0.739 (*) BEST
# Subject 2 FINAL BEST ACC: 73.90%
#
# Processing SUBJECT: 3
# Epoch 1/70 | Train Loss: 2.8624 | Val Loss: 3.3571 | Train Acc: 0.264 | Val Acc: 0.125 (*) BEST
# Epoch 3/70 | Train Loss: 1.6987 | Val Loss: 1.8746 | Train Acc: 0.285 | Val Acc: 0.164 (*) BEST
# Epoch 4/70 | Train Loss: 1.4729 | Val Loss: 1.6933 | Train Acc: 0.317 | Val Acc: 0.178 (*) BEST
# Epoch 5/70 | Train Loss: 1.3894 | Val Loss: 1.5649 | Train Acc: 0.327 | Val Acc: 0.213 (*) BEST
# Epoch 7/70 | Train Loss: 1.3478 | Val Loss: 1.5048 | Train Acc: 0.365 | Val Acc: 0.303 (*) BEST
# Epoch 17/70 | Train Loss: 1.0869 | Val Loss: 1.4645 | Train Acc: 0.602 | Val Acc: 0.415 (*) BEST
# Epoch 25/70 | Train Loss: 0.9459 | Val Loss: 1.2007 | Train Acc: 0.716 | Val Acc: 0.618 (*) BEST
# Epoch 31/70 | Train Loss: 0.8232 | Val Loss: 1.0927 | Train Acc: 0.792 | Val Acc: 0.638 (*) BEST
# Epoch 35/70 | Train Loss: 0.7635 | Val Loss: 0.9864 | Train Acc: 0.831 | Val Acc: 0.673 (*) BEST
# Epoch 37/70 | Train Loss: 0.7539 | Val Loss: 1.0891 | Train Acc: 0.835 | Val Acc: 0.697 (*) BEST
# Epoch 48/70 | Train Loss: 0.6869 | Val Loss: 0.9988 | Train Acc: 0.862 | Val Acc: 0.743 (*) BEST
# Epoch 58/70 | Train Loss: 0.6351 | Val Loss: 1.0719 | Train Acc: 0.881 | Val Acc: 0.757 (*) BEST
# Epoch 69/70 | Train Loss: 0.6270 | Val Loss: 0.9241 | Train Acc: 0.893 | Val Acc: 0.767 (*) BEST
# Subject 3 FINAL BEST ACC: 76.65%
#
# Processing SUBJECT: 4
# Epoch 1/70 | Train Loss: 2.0255 | Val Loss: 1.3429 | Train Acc: 0.259 | Val Acc: 0.382 (*) BEST
# Epoch 2/70 | Train Loss: 1.3998 | Val Loss: 1.2529 | Train Acc: 0.346 | Val Acc: 0.465 (*) BEST
# Epoch 4/70 | Train Loss: 1.2408 | Val Loss: 1.2935 | Train Acc: 0.458 | Val Acc: 0.500 (*) BEST
# Epoch 15/70 | Train Loss: 1.0410 | Val Loss: 1.1982 | Train Acc: 0.622 | Val Acc: 0.540 (*) BEST
# Epoch 16/70 | Train Loss: 1.0051 | Val Loss: 1.2415 | Train Acc: 0.644 | Val Acc: 0.555 (*) BEST
# Epoch 17/70 | Train Loss: 0.9425 | Val Loss: 1.0600 | Train Acc: 0.685 | Val Acc: 0.618 (*) BEST
# Epoch 18/70 | Train Loss: 0.9455 | Val Loss: 1.0884 | Train Acc: 0.685 | Val Acc: 0.634 (*) BEST
# Epoch 28/70 | Train Loss: 0.7022 | Val Loss: 1.0361 | Train Acc: 0.839 | Val Acc: 0.697 (*) BEST
# Epoch 29/70 | Train Loss: 0.6839 | Val Loss: 0.9784 | Train Acc: 0.855 | Val Acc: 0.763 (*) BEST
# Subject 4 FINAL BEST ACC: 76.29%
#
# Processing SUBJECT: 5
# Epoch 1/70 | Train Loss: 1.8123 | Val Loss: 1.3175 | Train Acc: 0.254 | Val Acc: 0.379 (*) BEST
# Epoch 2/70 | Train Loss: 1.4107 | Val Loss: 1.3071 | Train Acc: 0.311 | Val Acc: 0.559 (*) BEST
# Epoch 24/70 | Train Loss: 0.6494 | Val Loss: 1.3036 | Train Acc: 0.901 | Val Acc: 0.579 (*) BEST
# Epoch 26/70 | Train Loss: 0.6453 | Val Loss: 1.3125 | Train Acc: 0.893 | Val Acc: 0.592 (*) BEST
# Epoch 36/70 | Train Loss: 0.5841 | Val Loss: 1.5076 | Train Acc: 0.920 | Val Acc: 0.599 (*) BEST
# Epoch 49/70 | Train Loss: 0.5411 | Val Loss: 1.4215 | Train Acc: 0.948 | Val Acc: 0.625 (*) BEST
# Subject 5 FINAL BEST ACC: 62.50%
#
# Processing SUBJECT: 6
# Epoch 1/70 | Train Loss: 2.3069 | Val Loss: 1.8563 | Train Acc: 0.258 | Val Acc: 0.173 (*) BEST
# Epoch 4/70 | Train Loss: 1.3375 | Val Loss: 1.4106 | Train Acc: 0.384 | Val Acc: 0.235 (*) BEST
# Epoch 5/70 | Train Loss: 1.2962 | Val Loss: 1.3572 | Train Acc: 0.416 | Val Acc: 0.267 (*) BEST
# Epoch 6/70 | Train Loss: 1.2392 | Val Loss: 1.3790 | Train Acc: 0.483 | Val Acc: 0.268 (*) BEST
# Epoch 7/70 | Train Loss: 1.1896 | Val Loss: 1.3206 | Train Acc: 0.533 | Val Acc: 0.406 (*) BEST
# Epoch 15/70 | Train Loss: 0.8449 | Val Loss: 1.2282 | Train Acc: 0.772 | Val Acc: 0.542 (*) BEST
# Epoch 18/70 | Train Loss: 0.7594 | Val Loss: 1.2415 | Train Acc: 0.809 | Val Acc: 0.564 (*) BEST
# Epoch 27/70 | Train Loss: 0.5936 | Val Loss: 1.2289 | Train Acc: 0.912 | Val Acc: 0.689 (*) BEST
# Epoch 44/70 | Train Loss: 0.4942 | Val Loss: 1.0077 | Train Acc: 0.966 | Val Acc: 0.719 (*) BEST
# Epoch 48/70 | Train Loss: 0.4877 | Val Loss: 1.1952 | Train Acc: 0.969 | Val Acc: 0.724 (*) BEST
# Epoch 65/70 | Train Loss: 0.4696 | Val Loss: 0.9849 | Train Acc: 0.976 | Val Acc: 0.732 (*) BEST
# Epoch 67/70 | Train Loss: 0.4603 | Val Loss: 1.0242 | Train Acc: 0.981 | Val Acc: 0.743 (*) BEST
# Subject 6 FINAL BEST ACC: 74.26%
#
# Processing SUBJECT: 7
# Epoch 1/70 | Train Loss: 1.5776 | Val Loss: 1.4590 | Train Acc: 0.270 | Val Acc: 0.382 (*) BEST
# Epoch 2/70 | Train Loss: 1.2979 | Val Loss: 1.3235 | Train Acc: 0.390 | Val Acc: 0.392 (*) BEST
# Epoch 11/70 | Train Loss: 0.9759 | Val Loss: 1.2174 | Train Acc: 0.658 | Val Acc: 0.432 (*) BEST
# Epoch 13/70 | Train Loss: 0.9112 | Val Loss: 1.2514 | Train Acc: 0.719 | Val Acc: 0.456 (*) BEST
# Epoch 16/70 | Train Loss: 0.8585 | Val Loss: 1.1058 | Train Acc: 0.766 | Val Acc: 0.533 (*) BEST
# Epoch 17/70 | Train Loss: 0.8638 | Val Loss: 1.1119 | Train Acc: 0.761 | Val Acc: 0.673 (*) BEST
# Epoch 25/70 | Train Loss: 0.7216 | Val Loss: 0.9011 | Train Acc: 0.834 | Val Acc: 0.803 (*) BEST
# Epoch 40/70 | Train Loss: 0.5881 | Val Loss: 0.7484 | Train Acc: 0.921 | Val Acc: 0.829 (*) BEST
# Epoch 48/70 | Train Loss: 0.5671 | Val Loss: 0.7657 | Train Acc: 0.928 | Val Acc: 0.860 (*) BEST
# Epoch 54/70 | Train Loss: 0.5278 | Val Loss: 0.7332 | Train Acc: 0.948 | Val Acc: 0.873 (*) BEST
# Epoch 61/70 | Train Loss: 0.5102 | Val Loss: 0.7131 | Train Acc: 0.955 | Val Acc: 0.888 (*) BEST
# Epoch 69/70 | Train Loss: 0.4947 | Val Loss: 0.6894 | Train Acc: 0.969 | Val Acc: 0.934 (*) BEST
# Epoch 70/70 | Train Loss: 0.5066 | Val Loss: 0.6793 | Train Acc: 0.962 | Val Acc: 0.949 (*) BEST
# Subject 7 FINAL BEST ACC: 94.85%
#
# Processing SUBJECT: 8
# Epoch 1/70 | Train Loss: 1.6596 | Val Loss: 1.4169 | Train Acc: 0.284 | Val Acc: 0.327 (*) BEST
# Epoch 4/70 | Train Loss: 1.1697 | Val Loss: 1.3606 | Train Acc: 0.528 | Val Acc: 0.428 (*) BEST
# Epoch 7/70 | Train Loss: 0.9842 | Val Loss: 1.2810 | Train Acc: 0.645 | Val Acc: 0.452 (*) BEST
# Epoch 11/70 | Train Loss: 0.8888 | Val Loss: 1.2947 | Train Acc: 0.688 | Val Acc: 0.544 (*) BEST
# Epoch 21/70 | Train Loss: 0.7192 | Val Loss: 1.2784 | Train Acc: 0.829 | Val Acc: 0.555 (*) BEST
# Epoch 25/70 | Train Loss: 0.6652 | Val Loss: 1.0886 | Train Acc: 0.865 | Val Acc: 0.632 (*) BEST
# Epoch 27/70 | Train Loss: 0.6538 | Val Loss: 0.9771 | Train Acc: 0.866 | Val Acc: 0.699 (*) BEST
# Epoch 44/70 | Train Loss: 0.5608 | Val Loss: 0.9214 | Train Acc: 0.920 | Val Acc: 0.711 (*) BEST
# Epoch 52/70 | Train Loss: 0.5259 | Val Loss: 0.9185 | Train Acc: 0.950 | Val Acc: 0.715 (*) BEST
# Epoch 63/70 | Train Loss: 0.5026 | Val Loss: 0.8034 | Train Acc: 0.966 | Val Acc: 0.739 (*) BEST
# Subject 8 FINAL BEST ACC: 73.90%
#
# Processing SUBJECT: 9
# Epoch 1/70 | Train Loss: 1.6579 | Val Loss: 1.3764 | Train Acc: 0.309 | Val Acc: 0.311 (*) BEST
# Epoch 2/70 | Train Loss: 1.3294 | Val Loss: 1.2936 | Train Acc: 0.407 | Val Acc: 0.461 (*) BEST
# Epoch 4/70 | Train Loss: 1.1867 | Val Loss: 1.2533 | Train Acc: 0.501 | Val Acc: 0.463 (*) BEST
# Epoch 6/70 | Train Loss: 1.1376 | Val Loss: 1.2129 | Train Acc: 0.532 | Val Acc: 0.496 (*) BEST
# Epoch 7/70 | Train Loss: 1.1317 | Val Loss: 1.1468 | Train Acc: 0.530 | Val Acc: 0.506 (*) BEST
# Epoch 10/70 | Train Loss: 1.0525 | Val Loss: 1.0637 | Train Acc: 0.612 | Val Acc: 0.649 (*) BEST
# Epoch 13/70 | Train Loss: 0.9637 | Val Loss: 1.0103 | Train Acc: 0.677 | Val Acc: 0.653 (*) BEST
# Epoch 16/70 | Train Loss: 0.8697 | Val Loss: 1.0277 | Train Acc: 0.756 | Val Acc: 0.695 (*) BEST
# Epoch 25/70 | Train Loss: 0.6485 | Val Loss: 0.8442 | Train Acc: 0.891 | Val Acc: 0.779 (*) BEST
# Epoch 29/70 | Train Loss: 0.6200 | Val Loss: 0.8171 | Train Acc: 0.924 | Val Acc: 0.866 (*) BEST
# Subject 9 FINAL BEST ACC: 86.58%
#
# Processing SUBJECT: 10
# Epoch 1/70 | Train Loss: 2.3515 | Val Loss: 1.7756 | Train Acc: 0.243 | Val Acc: 0.320 (*) BEST
# Epoch 3/70 | Train Loss: 1.3862 | Val Loss: 1.2969 | Train Acc: 0.316 | Val Acc: 0.406 (*) BEST
# Epoch 6/70 | Train Loss: 1.2355 | Val Loss: 1.2280 | Train Acc: 0.456 | Val Acc: 0.528 (*) BEST
# Epoch 12/70 | Train Loss: 1.0465 | Val Loss: 1.2463 | Train Acc: 0.635 | Val Acc: 0.535 (*) BEST
# Epoch 14/70 | Train Loss: 0.9514 | Val Loss: 1.1073 | Train Acc: 0.710 | Val Acc: 0.631 (*) BEST
# Epoch 20/70 | Train Loss: 0.7661 | Val Loss: 1.0565 | Train Acc: 0.836 | Val Acc: 0.695 (*) BEST
# Epoch 33/70 | Train Loss: 0.5848 | Val Loss: 1.0965 | Train Acc: 0.933 | Val Acc: 0.732 (*) BEST
# Subject 10 FINAL BEST ACC: 73.16%
#
# Processing SUBJECT: 11
# Epoch 1/70 | Train Loss: 1.4684 | Val Loss: 1.4534 | Train Acc: 0.304 | Val Acc: 0.112 (*) BEST
# Epoch 2/70 | Train Loss: 1.3504 | Val Loss: 1.4771 | Train Acc: 0.355 | Val Acc: 0.261 (*) BEST
# Epoch 3/70 | Train Loss: 1.3288 | Val Loss: 1.4155 | Train Acc: 0.378 | Val Acc: 0.281 (*) BEST
# Epoch 4/70 | Train Loss: 1.3078 | Val Loss: 1.3458 | Train Acc: 0.388 | Val Acc: 0.325 (*) BEST
# Epoch 5/70 | Train Loss: 1.2644 | Val Loss: 1.4018 | Train Acc: 0.442 | Val Acc: 0.406 (*) BEST
# Epoch 6/70 | Train Loss: 1.2337 | Val Loss: 1.4235 | Train Acc: 0.469 | Val Acc: 0.467 (*) BEST
# Epoch 11/70 | Train Loss: 1.0898 | Val Loss: 1.2671 | Train Acc: 0.594 | Val Acc: 0.544 (*) BEST
# Epoch 26/70 | Train Loss: 0.8796 | Val Loss: 1.2119 | Train Acc: 0.735 | Val Acc: 0.550 (*) BEST
# Epoch 32/70 | Train Loss: 0.7961 | Val Loss: 1.2015 | Train Acc: 0.793 | Val Acc: 0.596 (*) BEST
# Epoch 54/70 | Train Loss: 0.6549 | Val Loss: 1.2599 | Train Acc: 0.876 | Val Acc: 0.651 (*) BEST
# Epoch 66/70 | Train Loss: 0.6237 | Val Loss: 1.2176 | Train Acc: 0.907 | Val Acc: 0.664 (*) BEST
# Subject 11 FINAL BEST ACC: 66.36%
#
# Processing SUBJECT: 12
# Epoch 1/70 | Train Loss: 2.9353 | Val Loss: 2.4137 | Train Acc: 0.255 | Val Acc: 0.140 (*) BEST
# Epoch 2/70 | Train Loss: 2.0703 | Val Loss: 1.8616 | Train Acc: 0.253 | Val Acc: 0.160 (*) BEST
# Epoch 3/70 | Train Loss: 1.6350 | Val Loss: 1.4826 | Train Acc: 0.270 | Val Acc: 0.191 (*) BEST
# Epoch 4/70 | Train Loss: 1.4252 | Val Loss: 1.3317 | Train Acc: 0.312 | Val Acc: 0.312 (*) BEST
# Epoch 6/70 | Train Loss: 1.3186 | Val Loss: 1.2565 | Train Acc: 0.402 | Val Acc: 0.439 (*) BEST
# Epoch 14/70 | Train Loss: 1.1262 | Val Loss: 1.5415 | Train Acc: 0.583 | Val Acc: 0.478 (*) BEST
# Epoch 26/70 | Train Loss: 0.8729 | Val Loss: 1.4623 | Train Acc: 0.770 | Val Acc: 0.480 (*) BEST
# Epoch 38/70 | Train Loss: 0.6171 | Val Loss: 1.3276 | Train Acc: 0.907 | Val Acc: 0.482 (*) BEST
# Epoch 50/70 | Train Loss: 0.5119 | Val Loss: 1.4180 | Train Acc: 0.965 | Val Acc: 0.504 (*) BEST
# Epoch 61/70 | Train Loss: 0.4728 | Val Loss: 1.3013 | Train Acc: 0.981 | Val Acc: 0.564 (*) BEST
# Subject 12 FINAL BEST ACC: 56.43%
#
# Processing SUBJECT: 13
# Epoch 1/70 | Train Loss: 3.1073 | Val Loss: 2.7203 | Train Acc: 0.252 | Val Acc: 0.173 (*) BEST
# Epoch 4/70 | Train Loss: 1.4822 | Val Loss: 1.5498 | Train Acc: 0.338 | Val Acc: 0.200 (*) BEST
# Epoch 5/70 | Train Loss: 1.3593 | Val Loss: 1.5234 | Train Acc: 0.371 | Val Acc: 0.309 (*) BEST
# Epoch 6/70 | Train Loss: 1.3119 | Val Loss: 1.5124 | Train Acc: 0.424 | Val Acc: 0.312 (*) BEST
# Epoch 10/70 | Train Loss: 1.1879 | Val Loss: 1.4087 | Train Acc: 0.518 | Val Acc: 0.485 (*) BEST
# Epoch 25/70 | Train Loss: 0.8901 | Val Loss: 1.6066 | Train Acc: 0.727 | Val Acc: 0.504 (*) BEST
# Epoch 30/70 | Train Loss: 0.8126 | Val Loss: 1.6929 | Train Acc: 0.776 | Val Acc: 0.524 (*) BEST
# Epoch 56/70 | Train Loss: 0.6059 | Val Loss: 1.4129 | Train Acc: 0.916 | Val Acc: 0.570 (*) BEST
# Subject 13 FINAL BEST ACC: 56.99%
#
# Processing SUBJECT: 14
# Epoch 1/70 | Train Loss: 2.7138 | Val Loss: 1.8397 | Train Acc: 0.260 | Val Acc: 0.320 (*) BEST
# Epoch 2/70 | Train Loss: 1.6410 | Val Loss: 1.3455 | Train Acc: 0.259 | Val Acc: 0.392 (*) BEST
# Epoch 20/70 | Train Loss: 0.6998 | Val Loss: 1.5277 | Train Acc: 0.841 | Val Acc: 0.504 (*) BEST
# Epoch 29/70 | Train Loss: 0.6565 | Val Loss: 1.7232 | Train Acc: 0.878 | Val Acc: 0.546 (*) BEST
# Epoch 33/70 | Train Loss: 0.6188 | Val Loss: 1.5104 | Train Acc: 0.902 | Val Acc: 0.566 (*) BEST
# Epoch 51/70 | Train Loss: 0.5621 | Val Loss: 1.7573 | Train Acc: 0.926 | Val Acc: 0.618 (*) BEST
# Epoch 62/70 | Train Loss: 0.5451 | Val Loss: 1.5170 | Train Acc: 0.942 | Val Acc: 0.621 (*) BEST
# Subject 14 FINAL BEST ACC: 62.13%
#
# Processing SUBJECT: 15
# Epoch 1/70 | Train Loss: 1.4551 | Val Loss: 1.2354 | Train Acc: 0.319 | Val Acc: 0.483 (*) BEST
# Epoch 2/70 | Train Loss: 1.2745 | Val Loss: 1.1792 | Train Acc: 0.445 | Val Acc: 0.676 (*) BEST
# Epoch 3/70 | Train Loss: 1.1412 | Val Loss: 1.1073 | Train Acc: 0.556 | Val Acc: 0.684 (*) BEST
# Epoch 5/70 | Train Loss: 1.0108 | Val Loss: 1.0473 | Train Acc: 0.624 | Val Acc: 0.779 (*) BEST
# Epoch 8/70 | Train Loss: 0.8483 | Val Loss: 0.9231 | Train Acc: 0.776 | Val Acc: 0.814 (*) BEST
# Epoch 10/70 | Train Loss: 0.7396 | Val Loss: 0.8272 | Train Acc: 0.856 | Val Acc: 0.877 (*) BEST
# Epoch 32/70 | Train Loss: 0.4482 | Val Loss: 0.6682 | Train Acc: 0.984 | Val Acc: 0.886 (*) BEST
# Epoch 44/70 | Train Loss: 0.4167 | Val Loss: 0.7567 | Train Acc: 0.997 | Val Acc: 0.906 (*) BEST
# Epoch 51/70 | Train Loss: 0.4101 | Val Loss: 0.7285 | Train Acc: 0.998 | Val Acc: 0.949 (*) BEST
# Subject 15 FINAL BEST ACC: 94.85%
#
# ==================================================
# FINAL RESULTS SUMMARY
# ==================================================
# Subjects: 15 | Average Accuracy: 73.76% | Std: 11.50
# Accuracies List: [77.57, 73.9, 76.65, 76.29, 62.5, 74.26, 94.85, 73.9, 86.58, 73.16, 66.36, 56.43, 56.99, 62.13, 94.85]
